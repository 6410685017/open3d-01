# %% [markdown]
# clip3
# 1. ให้ศึกษาค้นคว้า การ CROP
# 2. ให้สร้าง crop.json เพื่อตัดวส่วนหนึ่งของถนน (manually)

# %%
import open3d as o3d
print(o3d.__version__)
import numpy as np
#import polar as pl
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import json
# Out:
# /Users/pinnalin/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 0.18.0

# %%
path_iphone7_ply = "Dataset/iphone7.ply"
# path_kota_circuit2_ply = "Dataset/kota_circuit2.ply"

# %%
print("Load a ply point cloud, print it, and render it")
# ply_point_cloud = o3d.data.PLYPointCloud()
# pcd = o3d.io.read_point_cloud(ply_point_cloud.path)
pcd_iphone7 = o3d.io.read_point_cloud(path_iphone7_ply)
# pcd_kota_circuit2 = o3d.io.read_point_cloud(path_kota_circuit2_ply)
print("iphone7:\n", pcd_iphone7)
# print("kota_circuit2:\n", pcd_kota_circuit2)
# Out:
# Load a ply point cloud, print it, and render it
# iphone7:
#  PointCloud with 8076963 points.

# %% [markdown]
# open3d_file_io

# %% [markdown]
# pointclouds_document

# %%
'''
points np
'''
points_iphone7 = np.asarray(pcd_iphone7.points)
# points_kota_circuit2 = np.asarray(pcd_kota_circuit2.points
print("iphone7:\n", points_iphone7)
# print("kota_circuit2:\n", points_kota_circuit2)
# Out:
# iphone7:
#  [[-1033.32434082  1316.9284668  -1062.46020508]
#  [-1022.46795654  1315.88684082 -1062.16821289]
#  [-1011.65161133  1314.84265137 -1061.86083984]
#  ...
#  [15163.73046875  4870.33691406  -860.22692871]
#  [15154.33007812  4861.89550781  -859.56201172]
#  [15145.42675781  4854.18017578  -859.59936523]]

# %%
x_points = points_iphone7[:,0]
y_points = points_iphone7[:,1]
z_points = points_iphone7[:,2]
print(x_points)
print(y_points)
print(z_points)
# Out:
# [-1033.32434082 -1022.46795654 -1011.65161133 ... 15163.73046875
#  15154.33007812 15145.42675781]
# [1316.9284668  1315.88684082 1314.84265137 ... 4870.33691406 4861.89550781
#  4854.18017578]
# [-1062.46020508 -1062.16821289 -1061.86083984 ...  -860.22692871
#   -859.56201172  -859.59936523]

# %%
'''
colors np
'''
colors = np.asarray(pcd_iphone7.colors)
print(colors)
# Out:
# [[0.18431373 0.18431373 0.17647059]
#  [0.11764706 0.12156863 0.10196078]
#  [0.23137255 0.22352941 0.21176471]
#  ...
#  [0.64705882 0.63137255 0.58039216]
#  [0.6        0.57647059 0.53333333]
#  [0.59607843 0.58823529 0.54509804]]

# %%
fig = plt.figure(figsize=(18,16)) # Increase figure size to 18 inches by 16 inches
ax = fig.add_subplot(111,projection='3d')

ax.scatter(points_iphone7[:,0],points_iphone7[:,1],points_iphone7[:,2], c=colors, marker='o',alpha=0.6,edgecolors=colors)

ax.set_xlabel('X label')
ax.set_ylabel('Y label')
ax.set_zlabel('Z label')
plt.show()

# %%
import polars as pl

# Convert to Polars DataFrame
df = pl.DataFrame(points_iphone7)
# Define new column names
new_column_names = ['X','Y','Z']

# Rename the column
df = df.rename({old: new for old, new in zip(df.columns, new_column_names)})

# Show the DataFrame with new column names
print(df)
# Out:
# shape: (8_076_963, 3)
# ┌──────────────┬─────────────┬──────────────┐
# │ X            ┆ Y           ┆ Z            │
# │ ---          ┆ ---         ┆ ---          │
# │ f64          ┆ f64         ┆ f64          │
# ╞══════════════╪═════════════╪══════════════╡
# │ -1033.324341 ┆ 1316.928467 ┆ -1062.460205 │
# │ -1022.467957 ┆ 1315.886841 ┆ -1062.168213 │
# │ -1011.651611 ┆ 1314.842651 ┆ -1061.86084  │
# │ -1001.783142 ┆ 1314.170898 ┆ -1062.302856 │
# │ -991.04187   ┆ 1313.12207  ┆ -1061.966797 │
# │ …            ┆ …           ┆ …            │
# │ 15181.804688 ┆ 4885.897949 ┆ -859.907288  │
# │ 15173.189453 ┆ 4878.807129 ┆ -860.837341  │
# │ 15163.730469 ┆ 4870.336914 ┆ -860.226929  │
# │ 15154.330078 ┆ 4861.895508 ┆ -859.562012  │
# │ 15145.426758 ┆ 4854.180176 ┆ -859.599365  │
# └──────────────┴─────────────┴──────────────┘

# %%
x_min = df['X'].min()
y_min = df['Y'].min()
z_min = df['Z'].min()

x_max = df['X'].max()
y_max = df['Y'].max()
z_max = df['Z'].max()

# Display the minimum value
print("X: ", x_min, " - ", x_max)
print("Y: ", y_min, " - ", y_max)
print("Z: ", z_min, " - ", z_max)
# Out:
# X:  -4915.41162109375  -  17421.35546875
# Y:  -4588.701171875  -  6334.77734375
# Z:  -1340.43408203125  -  4766.04248046875

# %%
# Plotting the distribution using Seaborn
plt.figure(figsize=(10,6)) # Adjust the figure size as needed

# Histrogram with the Kernel Density Estimate (KED)
sns.histplot(df['X'], kde=True , color='red', bins=30, alpha=0.7, edgecolor='black')

# Alternitively, for just the KDE without the histogram, you can use sns.kdeplot:
# sns.kdeplot (df_pandas['X'], color='blue',shade=True)

plt.title('Distribution of X')
plt.xlabel('X')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
# Plotting the distribution using Seaborn
plt.figure(figsize=(10,6)) # Adjust the figure size as needed

# Histrogram with the Kernel Density Estimate (KED)
sns.histplot(df['Y'], kde=True , color='green', bins=30, alpha=0.7, edgecolor='black')

# Alternitively, for just the KDE without the histogram, you can use sns.kdeplot:
# sns.kdeplot (df_pandas['X'], color='blue',shade=True)

plt.title('Distribution of Y')
plt.xlabel('Y')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
# Plotting the distribution using Seaborn
plt.figure(figsize=(10,6)) # Adjust the figure size as needed

# Histrogram with the Kernel Density Estimate (KED)
sns.histplot(df['Z'], kde=True , color='blue', bins=30, alpha=0.7, edgecolor='black')

# Alternitively, for just the KDE without the histogram, you can use sns.kdeplot:
# sns.kdeplot (df_pandas['X'], color='blue',shade=True)

plt.title('Distribution of Z')
plt.xlabel('Z')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
 # z = [0:1000]
 # x = [:]
 # y = [1000:7000]

# %%
# Define the ranges for cropping
z_min, z_max = -3000, -800
y_min, y_max = -1500, 4900

# Create masks for each condition 
mask_z = (points_iphone7[:,2] >= z_min) & (points_iphone7[:,2] <= z_max)
mask_y = (points_iphone7[:,1] >= y_min) & (points_iphone7[:,1] <= y_max)

# Combine the masks using logical AND operation (you might use OR depending on your requirement)
combined_mask = mask_z & mask_y

# Apply the mask to the points and colors
cropped_points = points_iphone7[combined_mask]
cropped_colors = colors[combined_mask]

# Plotting
fig = plt.figure(figsize=(18,16))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(cropped_points[:,0], cropped_points[:,1],cropped_points[:,2], c = cropped_colors, marker='o', alpha=0.6,edgecolors=colors)

ax.set_xlabel('X label')
ax.set_ylabel('Y label')
ax.set_zlabel('Z label')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/backend_bases.py:2164, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2161     # we do this instead of `self.figure.draw_without_rendering`
#    2162     # so that we can inject the orientation
#    2163     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2164         self.figure.draw(renderer)
#    2165 if bbox_inches:
#    2166     if bbox_inches == "tight":
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/mpl_toolkits/mplot3d/axes3d.py:497, in Axes3D.draw(self, renderer)
#     494         axis.draw(renderer)
#     496 # Then rest
# --> 497 super().draw(renderer)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/artist.py:39, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      36     renderer.stop_rasterizing()
#      37     renderer._rasterizing = False
# ---> 39 return draw(artist, renderer, *args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mpl_toolkits/mplot3d/art3d.py:670, in Path3DCollection.draw(self, renderer)
#     668 with self._use_zordered_offset():
#     669     with cbook._setattr_cm(self, _in_draw=True):
# --> 670         super().draw(renderer)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/collections.py:1005, in _CollectionWithSizes.draw(self, renderer)
#    1002 @artist.allow_rasterization
#    1003 def draw(self, renderer):
#    1004     self.set_sizes(self._sizes, self.figure.dpi)
# -> 1005     super().draw(renderer)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/collections.py:379, in Collection.draw(self, renderer)
#     377 trans = self.get_transforms()
#     378 facecolors = self.get_facecolor()
# --> 379 edgecolors = self.get_edgecolor()
#     380 do_single_path_optimization = False
#     381 if (len(paths) == 1 and len(trans) <= 1 and
#     382         len(facecolors) == 1 and len(edgecolors) == 1 and
#     383         len(self._linewidths) == 1 and
#     384         all(ls[1] is None for ls in self._linestyles) and
#     385         len(self._antialiaseds) == 1 and len(self._urls) == 1 and
#     386         self.get_hatch() is None):
#
# File ~/Library/Python/3.9/lib/python/site-packages/mpl_toolkits/mplot3d/art3d.py:814, in Path3DCollection.get_edgecolor(self)
#     812 if cbook._str_equal(self._edgecolors, 'face'):
#     813     return self.get_facecolor()
# --> 814 return self._maybe_depth_shade_and_sort_colors(super().get_edgecolor())
#
# File ~/Library/Python/3.9/lib/python/site-packages/mpl_toolkits/mplot3d/art3d.py:797, in Path3DCollection._maybe_depth_shade_and_sort_colors(self, color_array)
#     795 def _maybe_depth_shade_and_sort_colors(self, color_array):
#     796     color_array = (
# --> 797         _zalpha(color_array, self._vzs)
#     798         if self._vzs is not None and self._depthshade
#     799         else color_array
#     800     )
#     801     if len(color_array) > 1:
#     802         color_array = color_array[self._z_markers_idx]
#
# File ~/Library/Python/3.9/lib/python/site-packages/mpl_toolkits/mplot3d/art3d.py:1170, in _zalpha(colors, zs)
#    1168 norm = Normalize(min(zs), max(zs))
#    1169 sats = 1 - norm(zs) * 0.7
# -> 1170 rgba = np.broadcast_to(mcolors.to_rgba_array(colors), (len(zs), 4))
#    1171 return np.column_stack([rgba[:, :3], rgba[:, 3] * sats])
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/lib/stride_tricks.py:413, in broadcast_to(array, shape, subok)
#     367 @array_function_dispatch(_broadcast_to_dispatcher, module='numpy')
#     368 def broadcast_to(array, shape, subok=False):
#     369     """Broadcast an array to a new shape.
#     370
#     371     Parameters
#    (...)
#     411            [1, 2, 3]])
#     412     """
# --> 413     return _broadcast_to(array, shape, subok=subok, readonly=True)
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/lib/stride_tricks.py:349, in _broadcast_to(array, shape, subok, readonly)
#     346     raise ValueError('all elements of broadcast shape must be non-'
#     347                      'negative')
#     348 extras = []
# --> 349 it = np.nditer(
#     350     (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
#     351     op_flags=['readonly'], itershape=shape, order='C')
#     352 with it:
#     353     # never really has writebackifcopy semantics
#     354     broadcast = it.itviews[0]
#
# ValueError: operands could not be broadcast together with remapped shapes [original->remapped]: (8076963,4)  and requested shape (6563860,4)

# %% [markdown]
# Crop

# %%
''' 
z_min, z_max = -3000, -800
y_min, y_max = -1500, 4900
'''
min_x, max_x = -4915.41162109375, 17421.35546875
min_y, max_y = -1500, 4900
min_z, max_z = -3000, -800

# %%
# Define the bounding box (AABB) for cropping
bbox = o3d.geometry.AxisAlignedBoundingBox(min_bound=(min_x, min_y, min_z), max_bound=(max_x, max_y, max_z))

# %%
# Prepare the data to be saved in JSON format
bbox_data = {
    "min_bound":bbox.min_bound.tolist(),
    "max_bound":bbox.max_bound.tolist()
}

# Save the bounding box data to JSON file
with open('bbox_data.json','w') as outfile:
    json.dump(bbox_data, outfile)

# %%
# Crop the point cloud
# cropped_pcd = pcd_iphone7.crop(bbox)

# Save the cropped point cloud to new .ply file
# o3d.io.write_point_cloud("cropped_point_cloud.ply", cropped_pcd)
# Out:
# True

# %%
# Load the bounding box data from the JSON file
with open('bbox_data.json','r') as infile:
    loaded_bbox_data = json.load(infile)

# Convert lists back to numpy arrays and create the bounding box
loaded_bbox = o3d.geometry.AxisAlignedBoundingBox(min_bound= loaded_bbox_data["min_bound"],
                                                  max_bound= loaded_bbox_data["max_bound"])

# %%
# Crop the point cloud using the loaded bounding box
cropped_pcd = pcd_iphone7.crop(loaded_bbox)

# Visualize the cropped point cloud (optional)
# o3d.visualization.draw_geometries([cropped_pcd_loaded])

# %%
# Crop the point cloud 
# cropped_pcd = pcd_iphone7.crop(loaded_bbox)

# Visualize the cropped point cloud (optional)
o3d.io.write_point_cloud("cropped_point_cloud.ply",cropped_pcd)
# Out:
# True

# %%
# Load the cropped point cloud from the saved .ply file
cropped_pcd_loaded = o3d.io.read_point_cloud("cropped_point_cloud.ply")

# Visualize the cropped point cloud
o3d.visualization.draw_geometries([cropped_pcd_loaded])
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# 2024-02-07 23:13:05.005 Python[25115:2279296] WARNING: Secure coding is automatically enabled for restorable state! However, not on all supported macOS versions of this application. Opt-in to secure coding explicitly by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState:.
# 2024-02-07 23:18:06.208 Python[25115:2279296] TSM AdjustCapsLockLEDForKeyTransitionHandling - _ISSetPhysicalKeyboardCapsLockLED Inhibit
